# %%
import pandas as pd
from river import stream,tree,metrics
import utils
from encoding import prefix_bin
import numpy as np
from sklearn.metrics import classification_report, accuracy_score
import os
from tqdm import tqdm
import sliding_window
import datetime, time
import importlib
importlib.reload(sliding_window)

import torch
from torch.utils.data import DataLoader,Dataset
import torch.nn as nn

import torch.nn.functional as F
import torch.optim as optim

# %%
file_name = './data/loan_baseline.pnml_noise_0.15_iteration_1_seed_614_sample.csv'


dataset = stream.iter_csv(
            file_name
#             './data/loan_baseline.pnml_noise_0.15_iteration_1_seed_614_simple.csv',
            )

totallength = len(list(dataset))

# %%
dataset = stream.iter_csv(
            file_name,
            drop=['noise', 'lifecycle:transition', 'Variant', 'Variant index'],
            )
enctype = 'Index-base'

# %%
key_pair = {
'Case ID':'caseid',
'Activity':'activity',
# 'Resource':'resource',
'Complete Timestamp':'ts',
}
catatars= ['activity']#,'resource']

case_dict ={}
training_models ={}

casecount = 0
rowcounter = 0
resultdict ={}
acc_dict ={}
prefix_wise_window = {}
prediction_result = {}
graceperiod_finish=0
finishedcases = set()

# %%
# Sliding window for training setting
window_size = 100
retraining_size = 20
training_window = sliding_window.training_window(window_size,retraining_size)

# %%
def display_progress(row_counting, total_length, interval=500):
    if rowcounter%interval == 0:
        print(round(rowcounter*100/totallength,2) ,'%', 'Case finished: %s'%(casecount), 'Running cases: %s'%(len(case_dict)))

# %%
class Customdataset():
    def __init__(self, dataset):
        '''
        Convert dataset to tensor
        
        Params
        dataset_type: Type of dataset, trainset, validset, and testset
        '''
        
        self.x_data=dataset[0]
        self.y_data=dataset[1]


    def preprocessing(self):
        x = self.x_data.to_numpy()
        x = np.reshape(x, (x.shape[0],1, x.shape[1]))
        y_set = sorted(set(self.y_data))
        train_y =[]
        for y in self.y_data:
            train_y.append(y_set.index(y))

        x_tensor = torch.tensor(x, dtype=torch.float)
        y_tensor = torch.tensor(train_y, dtype=torch.long)

        return x_tensor, y_tensor

# %%
class LSTM_model(nn.Module): # nn.Module inherit

    def __init__(self, input_x, raw_y):
        super(LSTM_model, self).__init__()
        
        self.input_size = input_x.shape[2]
        self.hidden_size =2* input_x.shape[2]
        self.num_case = input_x.shape[0]
        self.num_layers =2

        self.lstm = nn.LSTM(self.input_size, self.hidden_size, num_layers=num_layers, dropout=0.25, batch_first =False, bidirectional = False)

        self.h0 = torch.randn(num_layers, 1, self.hidden_size)
        self.c0 = torch.randn(num_layers, 1, self.hidden_size)

        latent_vector_size =50 * 1
        self.linear1 = nn.Linear(1 *self.num_case *self.hidden_size, latent_vector_size)
        self.linear_h = nn.Linear(1 *num_layers *self.hidden_size, latent_vector_size)
        self.linear_o = nn.Linear(3 * latent_vector_size, 1 *self.num_case * len(set(raw_y)))

        self.relu = nn.ReLU()


    def forward(self, input_x):
        output, (hn,cn) = self.lstm(input_x, (self.h0,self.c0))
        output = output.reshape((output.size()[0] *output.size()[1] *output.size()[2]))
        output = self.relu(self.linear1(output))

        uH = F.leaky_relu(self.linear_h(hn.reshape((hn.size()[0] *hn.size()[1] *hn.size()[2]))))
        uC = F.leaky_relu(self.linear_h(cn.reshape((cn.size()[0] *cn.size()[1] *cn.size()[2]))))
        output = torch.cat((uH ,uC ,output))
        output = self.linear_o(output)
        
        output =output.reshape(self.num_case,-1)

        return output

# %%
def training_stage(window, training_models):
    '''
    Manage training stage of streaming anomaly detection
    ----------
    Parameters
    window: class training_window
        Sliding window with training data
    training_models: dict
        Trained detector by prefix stored in. Default is randomforest
    ----------
    Return
    training_models
    '''
    pw_window = window.prefix_wise_window()
    for x in pw_window:
        training_x = pw_window[x][0]
        training_y = pw_window[x][1]
        
        dataset = pw_window[x]        
        x_tensor, y_tensor = Customdataset(dataset).preprocessing()  
        model = LSTM_model(x_tensor, training_y)
        optimizer = optim.Adam(model.parameters(), lr=0.01)
        optimizer.zero_grad()
        cross_entropy_loss = torch.nn.CrossEntropyLoss()
        loss_list =[]

        for i in range(10):
            output = model(x_tensor)
            loss = cross_entropy_loss(output, y_tensor)
            loss_list.append(loss.data)
            loss.backward()
            optimizer.step()
            
        if 'detector_%s'%(x) not in training_models:
            training_models['detector_%s'%(x)] =[0,0]
        training_models['detector_%s'%(x)][0] += 1
        training_models['detector_%s'%(x)][1] = model
    return training_models

# %%
def predict_activity_proba(last_event):
    '''
    Predict next activity prediction 
    
    Parameters
    ----------
    last_event: case_bin
    
    Return
    ----------
    modelid, prediction
    
    '''
    feature_matrix = prefix_wise_window['window_%s'%(last_event.prefix_length)][0].columns.values
    current_event = utils.readjustment_training(last_event.encoded, feature_matrix)
    current_event = pd.Series(current_event).to_frame().T
    prediction = [training_models['detector_window_%s'%(last_event.prefix_length)][1].predict_proba(current_event), training_models['detector_window_%s'%(last_event.prefix_length)][1].classes_]
    modelid = training_models['detector_window_%s'%(last_event.prefix_length)][0]

    return modelid, prediction

# %%
def first_event(case_bin):
    '''
    Generate start event before first event
    '''
    print(case_bin.event['ts'])
    empty_data ={'activity':'Start signal', 'ts':datetime.datetime.strftime(case_bin.event['ts'], '%Y-%m-%d %H:%M:%S')}
    start_event = prefix_bin(case_bin.caseid, empty_data)
    start_event.set_prefix_length(0)
    start_event.update_encoded(catattrs=catatars,enctype=enctype)
    start_event.update_truelabel(case_bin.event['activity'])
    return start_event

# %%
start_time = time.time()

for x,y in dataset:
    display_progress(rowcounter, totallength)
    rowcounter +=1
    
    utils.dictkey_chg(x, key_pair)
    # Event stream change dictionary keys
    x['ts'] = x['ts'][:-4]
    
    # Check label possible
    
    # Initialize case by prefix length
    caseid = x['caseid']
    x.pop('caseid')
    
    case_bin = prefix_bin(caseid, x)
    
    if caseid not in list(case_dict.keys()):
        case_dict[caseid] = []
        case_bin.set_prefix_length(1)
        
    elif caseid in finishedcases:
        continue
    
    else:
        case_bin.set_prefix_length(len(case_dict[caseid])+1)
        case_bin.set_prev_enc(case_dict[caseid][-1])
    
    # Encode event and cases and add to DB
    ts = case_bin.event['ts']
    case_bin.update_encoded(catattrs=catatars,enctype=enctype)
    
    # Set current activity as outcome of previous event
    if case_bin.prefix_length != 1:
        case_bin.prev_enc.update_truelabel(x['activity'])

    # First prediction for current event
    
    last_event = case_bin
    modelid = 'None'
    prediction = 'Not Available'

    if len(training_window.getAllitems()) !=0:
        if 'window_%s'%(last_event.prefix_length) in list(prefix_wise_window.keys()) and 'detector_window_%s'%(last_event.prefix_length) in training_models.keys():
            modelid, prediction = predict_activity_proba(last_event)
#             feature_matrix = prefix_wise_window['window_%s'%(last_event.prefix_length)][0].columns.values
#             current_event = utils.readjustment_training(last_event.encoded, feature_matrix)
#             current_event = pd.Series(current_event).to_frame().T
#             prediction = [training_models['detector_window_%s'%(last_event.prefix_length)][1].predict_proba(current_event), training_models['detector_window_%s'%(last_event.prefix_length)][1].classes_]
#             modelid = training_models['detector_window_%s'%(last_event.prefix_length)][0]
    case_bin.update_prediction((modelid, (prediction,ts)))        
            
    # Update training window and finish the case
    if x['activity'] == 'End':
        training_window.update_window({caseid: case_dict[caseid]})        
        if training_window.retraining == training_window.retraining_count:            
            training_models = training_stage(training_window, training_models)
            prefix_wise_window = training_window.prefix_wise_window()
            
        resultdict[caseid] = case_dict[caseid]
        case_dict.pop(caseid)

        casecount +=1
        for x in case_dict:
            last_event = case_dict[x][-1]
            modelid = 'None'
            prediction = 'Not Available'

            if len(training_window.getAllitems()) !=0:
                prefix_wise_window = training_window.prefix_wise_window()
                if 'window_%s'%(last_event.prefix_length) in list(prefix_wise_window.keys()) and 'detector_window_%s'%(last_event.prefix_length) in training_models.keys():
                    modelid, prediction = predict_activity_proba(last_event)

#                     feature_matrix = prefix_wise_window['window_%s'%(last_event.prefix_length)][0].columns.values
#                     current_event = utils.readjustment_training(last_event.encoded, feature_matrix)
#                     current_event = pd.Series(current_event).to_frame().T
#                     prediction = [training_models['detector_window_%s'%(last_event.prefix_length)][1].predict_proba(current_event), training_models['detector_window_%s'%(last_event.prefix_length)][1].classes_]
#                     modelid = training_models['detector_window_%s'%(last_event.prefix_length)][0]
            case_dict[x][-1].update_prediction((modelid, (prediction,ts)))        
        training_window.reset_retraining_count()
    else:
        case_dict[caseid].append(case_bin)


end_time = time.time()
# Out:
# 0.0 % Case finished: 0 Running cases: 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SUHWAN~1\AppData\Local\Temp/ipykernel_13732/3204940450.py in <module>
#      44     if len(training_window.getAllitems()) !=0:
#      45         if 'window_%s'%(last_event.prefix_length) in list(prefix_wise_window.keys()) and 'detector_window_%s'%(last_event.prefix_length) in training_models.keys():
# ---> 46             modelid, prediction = predict_activity_proba(last_event)
#      47 #             feature_matrix = prefix_wise_window['window_%s'%(last_event.prefix_length)][0].columns.values
#      48 #             current_event = utils.readjustment_training(last_event.encoded, feature_matrix)
#
# C:\Users\SUHWAN~1\AppData\Local\Temp/ipykernel_13732/1622725614.py in predict_activity_proba(last_event)
#      15     current_event = utils.readjustment_training(last_event.encoded, feature_matrix)
#      16     current_event = pd.Series(current_event).to_frame().T
# ---> 17     prediction = [training_models['detector_window_%s'%(last_event.prefix_length)][1].predict_proba(current_event), training_models['detector_window_%s'%(last_event.prefix_length)][1].classes_]
#      18     modelid = training_models['detector_window_%s'%(last_event.prefix_length)][0]
#      19
#
# c:\python\lib\site-packages\torch\nn\modules\module.py in __getattr__(self, name)
#    1175             if name in modules:
#    1176                 return modules[name]
# -> 1177         raise AttributeError("'{}' object has no attribute '{}'".format(
#    1178             type(self).__name__, name))
#    1179
#
# AttributeError: 'LSTM_model' object has no attribute 'predict_proba'

# %%
print(output)
print(y_tensor)
# print(training_window.prefix_wise_window())
# Out:
# tensor([[0.1230]], grad_fn=<ReshapeAliasBackward0>)
# tensor([0])

# %%
pw_window = training_window.prefix_wise_window()
batch_size =5
for x in pw_window:
    print(x)
    input_x = pw_window[x][0]
    input_y = pw_window[x][1]
    dataset = pw_window[x]
    x_tensor, y_tensor = Customdataset(dataset).preprocessing()  
    model = LSTM_model(x_tensor, input_y)
    optimizer = optim.Adam(model.parameters(), lr=0.01)
    optimizer.zero_grad()
    cross_entropy_loss = torch.nn.CrossEntropyLoss()
    loss_list =[]
    
    for i in range(10):
        output = model(x_tensor)
        loss = cross_entropy_loss(output, y_tensor)
        loss_list.append(loss.data)
        loss.backward()
        optimizer.step()
    print(loss_list)
    print('----------')
# Out:
# window_1
# [tensor(2.0893), tensor(1.8431), tensor(1.4981), tensor(1.0429), tensor(0.5478), tensor(0.1770), tensor(0.0325), tensor(0.0027), tensor(0.0001), tensor(1.6621e-06)]
# ----------
# window_2
# [tensor(1.6043), tensor(1.2714), tensor(0.5922), tensor(0.0663), tensor(0.0005), tensor(6.4714e-08), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_3
# [tensor(2.0307), tensor(1.0191), tensor(0.1945), tensor(0.0013), tensor(2.5545e-07), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_4
# [tensor(2.2901), tensor(1.3771), tensor(0.1515), tensor(0.0002), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_5
# [tensor(2.3390), tensor(1.1129), tensor(0.0347), tensor(1.2806e-06), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_6
# [tensor(2.1956), tensor(1.0520), tensor(0.0242), tensor(1.7711e-07), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_7
# [tensor(2.4483), tensor(0.6433), tensor(0.0025), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_8
# [tensor(2.4663), tensor(0.9509), tensor(0.0155), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_9
# [tensor(2.6255), tensor(1.1259), tensor(0.0001), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_10
# [tensor(2.6476), tensor(0.9599), tensor(0.0160), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_11
# [tensor(2.5566), tensor(0.8779), tensor(0.0305), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_12
# [tensor(2.7337), tensor(0.8056), tensor(0.0897), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_13
# [tensor(2.6282), tensor(0.7950), tensor(5.8659e-05), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_14
# [tensor(2.7191), tensor(0.7160), tensor(2.2650e-06), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_15
# [tensor(2.8480), tensor(1.5083), tensor(0.0008), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_16
# [tensor(2.4586), tensor(0.4904), tensor(2.1628e-06), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_17
# [tensor(2.2053), tensor(0.7718), tensor(1.3201e-05), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_18
# [tensor(2.4012), tensor(0.2934), tensor(4.9670e-07), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_19
# [tensor(2.1060), tensor(0.3481), tensor(1.3709e-06), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_20
# [tensor(1.5833), tensor(0.0516), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_21
# [tensor(1.3705), tensor(0.1188), tensor(4.4346e-06), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_22
# [tensor(1.3160), tensor(0.0150), tensor(2.3842e-08), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_23
# [tensor(1.5195), tensor(0.0611), tensor(9.5367e-08), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_24
# [tensor(1.0600), tensor(0.0241), tensor(5.0664e-07), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_25
# [tensor(1.1261), tensor(0.0613), tensor(9.5367e-07), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_26
# [tensor(1.0485), tensor(0.0106), tensor(2.9802e-08), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_27
# [tensor(1.3342), tensor(0.0183), tensor(5.9605e-08), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_28
# [tensor(1.1188), tensor(0.0318), tensor(2.7815e-07), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_29
# [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_30
# [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_31
# [tensor(0.7632), tensor(0.0087), tensor(3.5763e-07), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_32
# [tensor(0.7548), tensor(0.0200), tensor(1.2219e-05), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_33
# [tensor(0.6600), tensor(0.0067), tensor(1.2517e-06), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_34
# [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_35
# [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------
# window_36
# [tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)]
# ----------

# %%
import matplotlib.pyplot as plt
plt.plot(loss_list)
