# %%
import pickle
from matplotlib import pyplot as plt
from matplotlib import patches
import numpy as np
import matplotlib.dates as mdates
import pandas as pd
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('./data/loan_baseline.pnml_noise_0.15_iteration_1_seed_614_simple.csv')

# %%
with open('result_rf.pkl', 'rb') as fp:
    data = pickle.load(fp)

# %%
def anomalous_or_not(result, caseid):
    '''
    Determine following activity is anomalous or not
    If following activity is in the prediction candidates, it is normal. Otherwise, potential anomalous
    ----------
    Parameters
    result: dict
        Next activity prediction result
    caseid: str
    ----------
    Return
    anomalous_list: list
        List with each event is anomaloy or not
    '''
    anomalous_list=[]
    for x in result[caseid]:
        event = result[caseid][x]
        true_label = event[1]
        predictions = event[0]
        event_anomalous = 'Not Available'
        for y in list(predictions.values()):
            candidate_list = y[0]
            detection_result = 'Not Available'

            if candidate_list != 'Not Available':
                candidates = y[0][1]
                detection_result = 'Not Available'
                if true_label in candidates:
                    detection_result = 'Normal'
                else:
                    detection_result = 'Potential anomalous'
        event_anomalous = detection_result
        anomalous_list.append(event_anomalous)
    
    return anomalous_list

# %%
def anomalous_or_not_detail(result, caseid):
    '''
    Determine following activity is anomalous or not
    If following activity is in the prediction candidates, it is normal. Otherwise, potential anomalous
    ----------
    Parameters
    result: dict
        Next activity prediction result
    caseid: str
    ----------
    Return
    anomalous_list: list
        List with each event is anomaloy or not
    '''
    anomalous_list=[]
    for x in result[caseid]:
        anomalous_detail = []
        event = result[caseid][x]
        true_label = event[1]
        predictions = event[0]
        event_anomalous = 'Not Available'
        for y in list(predictions.values()):
            candidate_list = y[0]
            detection_result = 'Not Available'

            if candidate_list != 'Not Available':
                candidates = y[0][1]
                detection_result = 'Not Available'
                if true_label in candidates:
                    detection_result = 'Normal'
                else:
                    detection_result = 'Potential anomalous'
            anomalous_detail.append((detection_result, y[1]))
        anomalous_list.append(anomalous_detail)
    
    return anomalous_list

# %%
print(anomalous_result)
# Out:
# {'0': [[('Not Available', datetime.datetime(2017, 9, 15, 14, 46, 25))], [('Not Available', datetime.datetime(2017, 9, 15, 14, 46, 25))], [('Not Available', datetime.datetime(2017, 9, 15, 15, 14, 23))], [('Not Available', datetime.datetime(2017, 9, 15, 15, 14, 23))], [('Not Available', datetime.datetime(2017, 9, 15, 17, 15, 52))], [('Not Available', datetime.datetime(2017, 9, 15, 20, 34, 38))], [('Not Available', datetime.datetime(2017, 9, 15, 23, 14, 12))], [('Not Available', datetime.datetime(2017, 9, 15, 23, 25, 33))], [('Not Available', datetime.datetime(2017, 9, 16, 0, 40, 31))], [('Not Available', datetime.datetime(2017, 9, 16, 0, 43, 53))]], '1': [[('Not Available', datetime.datetime(2017, 9, 16, 0, 43, 53))], [('Not Available', datetime.datetime(2017, 9, 16, 0, 43, 53))], [('Not Available', datetime.datetime(2017, 9, 16, 16, 55, 30))], [('Not Available', datetime.datetime(2017, 9, 16, 18, 6, 10))], [('Not Available', datetime.datetime(2017, 9, 16, 18, 38, 29))], [('Not Available', datetime.datetime(2017, 9, 16, 18, 51, 19))], [('Not Available', datetime.datetime(2017, 9, 16, 21, 58, 19))], [('Not Available', datetime.datetime(2017, 9, 16, 23, 30, 39))], [('Not Available', datetime.datetime(2017, 9, 17, 1, 20, 35))], [('Not Available', datetime.datetime(2017, 9, 17, 1, 22, 23))], [('Not Available', datetime.datetime(2017, 9, 17, 2, 20, 56))], [('Not Available', datetime.datetime(2017, 9, 17, 2, 27, 22))], [('Not Available', datetime.datetime(2017, 9, 17, 2, 32, 43))]], '2': [[('Not Available', datetime.datetime(2017, 9, 17, 1, 17, 29))], [('Not Available', datetime.datetime(2017, 9, 17, 1, 17, 29))], [('Not Available', datetime.datetime(2017, 9, 17, 1, 17, 29))], [('Not Available', datetime.datetime(2017, 9, 17, 2, 22, 24))], [('Not Available', datetime.datetime(2017, 9, 17, 3, 11, 57))], [('Not Available', datetime.datetime(2017, 9, 17, 5, 29, 5))], [('Not Available', datetime.datetime(2017, 9, 17, 9, 1, 5))], [('Not Available', datetime.datetime(2017, 9, 17, 9, 1, 5))], [('Not Available', datetime.datetime(2017, 9, 17, 10, 38, 4))], [('Not Available', datetime.datetime(2017, 9, 17, 11, 52, 11))], [('Not Available', datetime.datetime(2017, 9, 17, 12, 23, 53))]], '3': [[('Not Available', datetime.datetime(2017, 9, 17, 4, 59, 51))], [('Not Available', datetime.datetime(2017, 9, 17, 4, 59, 51))], [('Not Available', datetime.datetime(2017, 9, 17, 4, 59, 51))], [('Not Available', datetime.datetime(2017, 9, 17, 5, 17, 58))], [('Not Available', datetime.datetime(2017, 9, 17, 5, 25, 24))], [('Not Available', datetime.datetime(2017, 9, 17, 6, 45, 44))], [('Not Available', datetime.datetime(2017, 9, 17, 6, 48, 48))], [('Not Available', datetime.datetime(2017, 9, 17, 7, 41, 45))], [('Not Available', datetime.datetime(2017, 9, 17, 7, 45, 52))], [('Not Available', datetime.datetime(2017, 9, 17, 8, 33, 4))], [('Not Available', datetime.datetime(2017, 9, 17, 8, 33, 4))], [('Not Available', datetime.datetime(2017, 9, 17, 9, 17, 24))], [('Not Available', datetime.datetime(2017, 9, 17, 9, 38, 21))], [('Not Available', datetime.datetime(2017, 9, 17, 9, 38, 21))], [('Not Available', datetime.datetime(2017, 9, 17, 11, 50, 12))]], '4': [[('Not Available', datetime.datetime(2017, 9, 17, 11, 50, 12))], [('Not Available', datetime.datetime(2017, 9, 17, 11, 50, 12))], [('Not Available', datetime.datetime(2017, 9, 17, 19, 59, 40))], [('Not Available', datetime.datetime(2017, 9, 17, 19, 59, 40))], [('Not Available', datetime.datetime(2017, 9, 17, 20, 19, 47))], [('Not Available', datetime.datetime(2017, 9, 17, 20, 21, 45))], [('Not Available', datetime.datetime(2017, 9, 17, 20, 26, 2))], [('Not Available', datetime.datetime(2017, 9, 17, 20, 43, 53))], [('Not Available', datetime.datetime(2017, 9, 17, 21, 17, 51))], [('Not Available', datetime.datetime(2017, 9, 17, 21, 17, 51))], [('Not Available', datetime.datetime(2017, 9, 17, 21, 49, 7))], [('Not Available', datetime.datetime(2017, 9, 17, 22, 44, 24))], [('Not Available', datetime.datetime(2017, ...

# %%
caseidlist = list(data.keys())
anomalous_result ={}
for caseid in caseidlist:
    anomalous_result[caseid]= anomalous_or_not_detail(data, caseid)

# %%
print(df.head)
print(df['noise'])
# Out:
# <bound method NDFrame.head of       Case ID                                Activity  \
# 0           0                                   Start
# 1           0  start_event_Loan  application received
# 2           0   Check  application  form completeness
# 3           0                    Send acceptance pack
# 4           0                       Appraise property
# ...       ...                                     ...
# 8609      525                        Assess loan risk
# 8610      525                      Assess eligibility
# 8611      525                      Reject application
# 8612      525     end_event_Loan application rejected
# 8613      525                                     End
#
#            Complete Timestamp      Variant  Variant index  \
# 0     2017-09-15 14:46:25.000   Variant 17             17
# 1     2017-09-15 14:46:25.000   Variant 17             17
# 2     2017-09-15 15:14:23.349   Variant 17             17
# 3     2017-09-15 15:14:23.349   Variant 17             17
# 4     2017-09-15 17:15:52.828   Variant 17             17
# ...                       ...          ...            ...
# 8609  2018-12-31 18:15:08.422  Variant 472            472
# 8610  2018-12-31 19:29:43.172  Variant 472            472
# 8611  2018-12-31 22:31:29.104  Variant 472            472
# 8612  2018-12-31 23:49:41.599  Variant 472            472
# 8613  2018-12-31 23:49:41.599  Variant 472            472
#
#      lifecycle:transition  noise
# 0                   Start  Start
# 1                complete    NaN
# 2                complete    NaN
# 3                     NaN   true
# 4                complete    NaN
# ...                   ...    ...
# 8609             complete    NaN
# 8610             complete    NaN
# 8611             complete    NaN
# 8612             complete    NaN
# 8613                  End    End
#
# [8614 rows x 7 columns]>
# 0       Start
# 1         NaN
# 2         NaN
# 3        true
# 4         NaN
#         ...
# 8609      NaN
# 8610      NaN
# 8611      NaN
# 8612      NaN
# 8613      End
# Name: noise, Length: 8614, dtype: object

# %%
true_labels = []

for pos, x in enumerate(list(df['noise'])):
    if list(df['Activity'])[pos] != 'End':
        if x == 'Start':
            x = np.nan

        true_labels.append(x)
print(len(true_labels))
# Out:
# 8088

# %%
case_event_result_dict = {}
predicted_labels = []
for x in anomalous_result:
    case_event_result_dict[x] = []
    for pos, t in enumerate(anomalous_result[x]):
        case_event_result_dict[x].append([pos+1, t[0][0]])
        predicted_labels.append(t[0][0])
print(len(predicted_labels))
# Out:
# 8088

# %%
total_predictions  =0
correct_prediction =0
true_label =0

true_label2=[]
predict_label2=[]
for pos,t in enumerate(predicted_labels):
    if predicted_labels[pos] != 'Not Available':
        if true_labels[pos] == 'true':
            true_label = 'Potential anomalous'
        elif np.isnan(true_labels[pos]):
            true_label = 'Normal'
        
        true_label2.append(true_label)
        predict_label2.append(predicted_labels[pos])
        if true_label == predicted_labels[pos]:
            correct_prediction +=1
        total_predictions +=1
print(correct_prediction, total_predictions)
print(correct_prediction/total_predictions)
# Out:
# 5448 7841
# 0.6948093355439358

# %%
print(classification_report(true_label2, predict_label2))
# Out:
#                      precision    recall  f1-score   support
#
#              Normal       0.86      0.77      0.81      6810
# Potential anomalous       0.12      0.21      0.15      1031
#
#            accuracy                           0.69      7841
#           macro avg       0.49      0.49      0.48      7841
#        weighted avg       0.77      0.69      0.73      7841
